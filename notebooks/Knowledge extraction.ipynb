# %% [markdown]
# ## Import the Extraction Function
# !pip install -r ../requirements.txt
#
# Clearly import the custom extraction function from the `src/extraction.py` module.

# %%
import sys
from pathlib import Path

# Clearly add parent directory (to access src folder)
sys.path.append(str(Path.cwd().parent))

# Import your extraction function explicitly
from src.extraction import extract_json_from_text

# %% [markdown]
# ## Define File Paths
#
# Clearly specify paths to:
#
# - Input text file (`example.txt`)
# - Ontology YAML file (`urban_air_quality.yaml`)
# - Output JSON file (`extracted_knowledge.json`)
# - LLM model file (`.gguf` model file)

# %%
# Clearly defined file paths
input_txt_path = Path("../data/example txt/example.txt")
ontology_yaml_path = Path("../ontology/urban_air_quality.yaml")
hints_file_path = Path("../src/prompt_hints.md")
output_json_path = Path("../data/output/extracted_knowledge.json")
model_path = Path("/Users/nxx20/Library/Application Support/nomic.ai/GPT4All/mistral-7b-instruct-v0.2.Q4_K_M.gguf")  # <-- explicitly replace this path

# %% [markdown]
# ## Run Extraction Function
#
# Execute the extraction function clearly to generate the structured JSON output.

# %%
extract_json_from_text(
    input_txt_path=input_txt_path,
    ontology_yaml_path=ontology_yaml_path,
    hints_file_path=hints_file_path,
    output_json_path=output_json_path,
    model_path=model_path
)
# Out:
# llama_model_load_from_file_impl: using device Metal (Apple M3 Pro) - 12287 MiB free
# llama_model_loader: loaded meta data with 24 key-value pairs and 291 tensors from /Users/nxx20/Library/Application Support/nomic.ai/GPT4All/mistral-7b-instruct-v0.2.Q4_K_M.gguf (version GGUF V3 (latest))
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = mistralai_mistral-7b-instruct-v0.2
# llama_model_loader: - kv   2:                       llama.context_length u32              = 32768
# llama_model_loader: - kv   3:                     llama.embedding_length u32              = 4096
# llama_model_loader: - kv   4:                          llama.block_count u32              = 32
# llama_model_loader: - kv   5:                  llama.feed_forward_length u32              = 14336
# llama_model_loader: - kv   6:                 llama.rope.dimension_count u32              = 128
# llama_model_loader: - kv   7:                 llama.attention.head_count u32              = 32
# llama_model_loader: - kv   8:              llama.attention.head_count_kv u32              = 8
# llama_model_loader: - kv   9:     llama.attention.layer_norm_rms_epsilon f32              = 0.000010
# llama_model_loader: - kv  10:                       llama.rope.freq_base f32              = 1000000.000000
# llama_model_loader: - kv  11:                          general.file_type u32              = 15
# llama_model_loader: - kv  12:                       tokenizer.ggml.model str              = llama
# llama_model_loader: - kv  13:                      tokenizer.ggml.tokens arr[str,32000]   = ["<unk>", "<s>", "</s>", "<0x00>", "<...
# llama_model_loader: - kv  14:                      tokenizer.ggml.scores arr[f32,32000]   = [0.000000, 0.000000, 0.000000, 0.0000...
# llama_model_loader: - kv  15:                  tokenizer.ggml.token_type arr[i32,32000]   = [2, 3, 3, 6, 6, 6, 6, 6, 6, 6, 6, 6, ...
# llama_model_loader: - kv  16:                tokenizer.ggml.bos_token_id u32              = 1
# llama_model_loader: - kv  17:                tokenizer.ggml.eos_token_id u32              = 2
# llama_model_loader: - kv  18:            tokenizer.ggml.unknown_token_id u32              = 0
# llama_model_loader: - kv  19:            tokenizer.ggml.padding_token_id u32              = 0
# llama_model_loader: - kv  20:               tokenizer.ggml.add_bos_token bool             = true
# llama_model_loader: - kv  21:               tokenizer.ggml.add_eos_token bool             = false
# llama_model_loader: - kv  22:                    tokenizer.chat_template str              = {{ bos_token }}{% for message in mess...
# llama_model_loader: - kv  23:               general.quantization_version u32              = 2
# llama_model_loader: - type  f32:   65 tensors
# llama_model_loader: - type q4_K:  193 tensors
# llama_model_loader: - type q6_K:   33 tensors
# print_info: file format = GGUF V3 (latest)
# print_info: file type   = Q4_K - Medium
# print_info: file size   = 4.07 GiB (4.83 BPW)
# init_tokenizer: initializing tokenizer for type 1
# load: control token:      2 '</s>' is not marked as EOG
# load: control token:      1 '<s>' is not marked as EOG
# load: special_eos_id is not in special_eog_ids - the tokenizer config may be incorrect
# load: special tokens cache size = 3
# load: token to piece cache size = 0.1637 MB
# print_info: arch             = llama
# print_info: vocab_only       = 0
# print_info: n_ctx_train      = 32768
# print_info: n_embd           = 4096
# print_info: n_layer          = 32
# print_info: n_head           = 32
# print_info: n_head_kv        = 8
# print_info: n_rot            = 128
# print_info: n_swa            = 0
# print_info: n_embd_head_k    = 128
# print_info: n_embd_head_v    = 128
# print_info: n_gqa            = 4
# print_info: n_embd_k_gqa     = 1024
# print_info: n_embd_v_gqa     = 1024
# print_info: f_norm_eps       = 0.0e+00
# print_info: f_norm_rms_eps   = 1.0e-05
# print_info: f_clamp_kqv      = 0.0e+00
# print_info: f_max_alibi_bias = 0.0e+00
# print_info: f_logit_scale    = 0.0e+00
# print_info: f_attn_scale     = 0.0e+00
# print_info: n_ff             = 14336
# print_info: n_expert         = 0
# print_info: n_expert_used    = 0
# print_info: causal attn      = 1
# print_info: pooling type     = 0
# print_info: rope type        = 0
# print_info: rope scaling     = linear
# print_info: freq_base_train  = 1000000.0
# print_info: freq_scale_train = 1
# print_info: n_ctx_orig_yarn  = 32768
# print_info: rope_finetuned   = unknown
# print_info: ssm_d_conv       = 0
# print_info: ssm_d_inner      = 0
# print_info: ssm_d_state      = 0
# print_info: ssm_dt_rank      = 0
# print_info: ssm_dt_b_c_rms   = 0
# print_info: model type       = 7B
# print_info: model params     = 7.24 B
# print_info: general.name     = mistralai_mistral-7b-instruct-v0.2
# print_info: vocab type       = SPM
# print_info: n_vocab          = 32000
# print_info: n_merges         = 0
# print_info: BOS token        = 1 '<s>'
# print_info: EOS token        = 2 '</s>'
# print_info: UNK token        = 0 '<unk>'
# print_info: PAD token        = 0 '<unk>'
# print_info: LF token         = 13 '<0x0A>'
# print_info: EOG token        = 2 '</s>'
# print_info: max token length = 48
# load_tensors: loading model tensors, this can take a while... (mmap = true)
# load_tensors: layer   0 assigned to device CPU
# load_tensors: layer   1 assigned to device CPU
# load_tensors: layer   2 assigned to device CPU
# load_tensors: layer   3 assigned to device CPU
# load_tensors: layer   4 assigned to device CPU
# load_tensors: layer   5 assigned to device CPU
# load_tensors: layer   6 assigned to device CPU
# load_tensors: layer   7 assigned to device CPU
# load_tensors: layer   8 assigned to device CPU
# load_tensors: layer   9 assigned to device CPU
# load_tensors: layer  10 assigned to device CPU
# load_tensors: layer  11 assigned to device CPU
# load_tensors: layer  12 assigned to device CPU
# load_tensors: layer  13 assigned to device CPU
# load_tensors: layer  14 assigned to device CPU
# load_tensors: layer  15 assigned to device CPU
# load_tensors: layer  16 assigned to device CPU
# load_tensors: layer  17 assigned to device CPU
# load_tensors: layer  18 assigned to device CPU
# load_tensors: layer  19 assigned to device CPU
# load_tensors: layer  20 assigned to device CPU
# load_tensors: layer  21 assigned to device CPU
# load_tensors: layer  22 assigned to device CPU
# load_tensors: layer  23 assigned to device CPU
# load_tensors: layer  24 assigned to device CPU
# load_tensors: layer  25 assigned to device CPU
# load_tensors: layer  26 assigned to device CPU
# load_tensors: layer  27 assigned to device CPU
# load_tensors: layer  28 assigned to device CPU
# load_tensors: layer  29 assigned to device CPU
# load_tensors: layer  30 assigned to device CPU
# load_tensors: layer  31 assigned to device CPU
# load_tensors: layer  32 assigned to device CPU
# load_tensors: tensor 'token_embd.weight' (q4_K) (and 290 others) cannot be used with preferred buffer type CPU_AARCH64, using CPU instead
# load_tensors: offloading 0 repeating layers to GPU
# load_tensors: offloaded 0/33 layers to GPU
# load_tensors:   CPU_Mapped model buffer size =  4165.37 MiB
# .................................................................................................
# llama_init_from_model: n_seq_max     = 1
# llama_init_from_model: n_ctx         = 8192
# llama_init_from_model: n_ctx_per_seq = 8192
# llama_init_from_model: n_batch       = 512
# llama_init_from_model: n_ubatch      = 512
# llama_init_from_model: flash_attn    = 0
# llama_init_from_model: freq_base     = 1000000.0
# llama_init_from_model: freq_scale    = 1
# llama_init_from_model: n_ctx_per_seq (8192) < n_ctx_train (32768) -- the full capacity of the model will not be utilized
# ggml_metal_init: allocating
# ggml_metal_init: found device: Apple M3 Pro
# ggml_metal_init: picking default device: Apple M3 Pro
# ggml_metal_load_library: using embedded metal library
# ggml_metal_init: GPU name:   Apple M3 Pro
# ggml_metal_init: GPU family: MTLGPUFamilyApple9  (1009)
# ggml_metal_init: GPU family: MTLGPUFamilyCommon3 (3003)
# ggml_metal_init: GPU family: MTLGPUFamilyMetal3  (5001)
# ggml_metal_init: simdgroup reduction   = true
# ggml_metal_init: simdgroup matrix mul. = true
# ggml_metal_init: has residency sets    = true
# ggml_metal_init: has bfloat            = true
# ggml_metal_init: use bfloat            = false
# ggml_metal_init: hasUnifiedMemory      = true
# ggml_metal_init: recommendedMaxWorkingSetSize  = 12884.92 MB
# ggml_metal_init: loaded kernel_add                                    0x14ce1a120 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_add_row                                0x14ce2c5c0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_sub                                    0x14ce1e650 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_sub_row                                0x11e14f5f0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul                                    0x14ce30370 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_row                                0x11e14f8b0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_div                                    0x11e14fb70 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_div_row                                0x11e03cd00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_repeat_f32                             0x14ce30630 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_repeat_f16                             0x14ce30aa0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_repeat_i32                             0x12cf59c10 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_repeat_i16                             0x11e03d2e0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_scale                                  0x11e03dbd0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_scale_4                                0x11e03e350 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_clamp                                  0x14ce31280 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_tanh                                   0x11e03ea40 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_relu                                   0x12cf5b9b0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_sigmoid                                0x11e03f130 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_gelu                                   0x11e1500b0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_gelu_4                                 0x12cf5d6a0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_gelu_quick                             0x12cf5dd90 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_gelu_quick_4                           0x11e03f820 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_silu                                   0x11e03ff10 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_silu_4                                 0x11e1507a0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_elu                                    0x11e150e90 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_soft_max_f16                           0x11e040380 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_soft_max_f16_4                         0x11e0407f0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_soft_max_f32                           0x12cf5e5e0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_soft_max_f32_4                         0x14ce316f0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_diag_mask_inf                          0x11e040c60 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_diag_mask_inf_8                        0x12cf5e8a0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_f32                           0x12cf5ed10 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_f16                           0x14ce31b60 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_get_rows_bf16                     (not supported)
# ggml_metal_init: loaded kernel_get_rows_q4_0                          0x12cf5efd0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q4_1                          0x12cf5f440 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q5_0                          0x11e151300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q5_1                          0x11e0410d0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q8_0                          0x11e041540 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q2_K                          0x11e0419b0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q3_K                          0x11e041e20 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q4_K                          0x12cf60650 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q5_K                          0x12cf60910 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q6_K                          0x12cf60d80 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq2_xxs                       0x14ce31fd0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq2_xs                        0x14ce32440 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq3_xxs                       0x11e042290 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq3_s                         0x14ce328b0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq2_s                         0x107691b60 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq1_s                         0x11e305470 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq1_m                         0x12cf611f0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq4_nl                        0x14ce32d20 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq4_xs                        0x11e205690 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_i32                           0x12cf614b0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_rms_norm                               0x12cf61770 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_group_norm                             0x14ce32fe0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_norm                                   0x107691e20 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_ssm_conv_f32                           0x107525be0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_ssm_scan_f32                           0x12cf61a30 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_f32_f32                         0x12ce397f0 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_mul_mv_bf16_f32                   (not supported)
# ggml_metal_init: skipping kernel_mul_mv_bf16_f32_1row              (not supported)
# ggml_metal_init: skipping kernel_mul_mv_bf16_f32_l4                (not supported)
# ggml_metal_init: skipping kernel_mul_mv_bf16_bf16                  (not supported)
# ggml_metal_init: loaded kernel_mul_mv_f16_f32                         0x12cf61cf0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_f16_f32_1row                    0x11e151770 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_f16_f32_l4                      0x12cf61fb0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_f16_f16                         0x12cf62270 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q4_0_f32                        0x11e042700 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q4_1_f32                        0x14ce33450 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q5_0_f32                        0x11e151a30 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q5_1_f32                        0x11cf46680 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q8_0_f32                        0x12cf62bf0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_f16_f32_r1_2                0x11e151ea0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_f16_f32_r1_3                0x12cf62eb0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_f16_f32_r1_4                0x14ce33710 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_f16_f32_r1_5                0x11e152670 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_0_f32_r1_2               0x11e0429c0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_0_f32_r1_3               0x12cf63170 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_0_f32_r1_4               0x11e042e30 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_0_f32_r1_5               0x11e0430f0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_1_f32_r1_2               0x11e043560 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_1_f32_r1_3               0x11e043820 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_1_f32_r1_4               0x11cf46940 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_1_f32_r1_5               0x11e043c90 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_0_f32_r1_2               0x12cf635e0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_0_f32_r1_3               0x12cf63a50 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_0_f32_r1_4               0x12cf63ec0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_0_f32_r1_5               0x11e152930 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_1_f32_r1_2               0x11cf46c00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_1_f32_r1_3               0x11cf46ec0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_1_f32_r1_4               0x12cf64330 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_1_f32_r1_5               0x12cf645f0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q8_0_f32_r1_2               0x11e2061d0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q8_0_f32_r1_3               0x11e044100 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q8_0_f32_r1_4               0x11e152bf0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q8_0_f32_r1_5               0x11cf47180 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_K_f32_r1_2               0x11e044570 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_K_f32_r1_3               0x11e0449e0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_K_f32_r1_4               0x11cf48190 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_K_f32_r1_5               0x11e044ca0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_K_f32_r1_2               0x12cf64a60 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_K_f32_r1_3               0x12cf64ed0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_K_f32_r1_4               0x12cf65340 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_K_f32_r1_5               0x11e045110 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q6_K_f32_r1_2               0x12cf657b0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q6_K_f32_r1_3               0x11e152eb0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q6_K_f32_r1_4               0x12cf65c20 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q6_K_f32_r1_5               0x11cf48450 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_iq4_nl_f32_r1_2             0x11cf488c0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_iq4_nl_f32_r1_3             0x12cf66240 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_iq4_nl_f32_r1_4             0x11cf48b80 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_iq4_nl_f32_r1_5             0x11cf48ff0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q2_K_f32                        0x11cf49460 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q3_K_f32                        0x11e1534d0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q4_K_f32                        0x11cf498d0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q5_K_f32                        0x11cf4a970 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q6_K_f32                        0x11cf4ade0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq2_xxs_f32                     0x11cf4b250 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq2_xs_f32                      0x11cf4b510 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq3_xxs_f32                     0x12cf66500 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq3_s_f32                       0x12cf66970 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq2_s_f32                       0x12cf66de0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq1_s_f32                       0x12cf676a0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq1_m_f32                       0x12cf67960 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq4_nl_f32                      0x12cf67c20 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq4_xs_f32                      0x11cf4bb30 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_f32_f32                      0x11cf4bfa0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_f16_f32                      0x11cf4c410 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_mul_mv_id_bf16_f32                (not supported)
# ggml_metal_init: loaded kernel_mul_mv_id_q4_0_f32                     0x11e153790 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q4_1_f32                     0x12cf67ee0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q5_0_f32                     0x12cf68350 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q5_1_f32                     0x12cf68610 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q8_0_f32                     0x11e153db0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q2_K_f32                     0x11cf4c880 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q3_K_f32                     0x12cf68c30 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q4_K_f32                     0x11e154070 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q5_K_f32                     0x11e1544e0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q6_K_f32                     0x11e045c40 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq2_xxs_f32                  0x11cf4ccf0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq2_xs_f32                   0x11cf4d160 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq3_xxs_f32                  0x11e154950 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq3_s_f32                    0x12cf690a0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq2_s_f32                    0x12cf69510 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq1_s_f32                    0x12cf697d0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq1_m_f32                    0x12cf69c40 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq4_nl_f32                   0x11cf4d5d0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq4_xs_f32                   0x11cf4da40 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_f32_f32                         0x11e154dc0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_f16_f32                         0x12cf6a0b0 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_mul_mm_bf16_f32                   (not supported)
# ggml_metal_init: loaded kernel_mul_mm_q4_0_f32                        0x11e046410 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q4_1_f32                        0x11e155230 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q5_0_f32                        0x11e1556a0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q5_1_f32                        0x12cf6a370 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q8_0_f32                        0x11e046880 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q2_K_f32                        0x11e046cf0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q3_K_f32                        0x11e047160 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q4_K_f32                        0x12cf6a7e0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q5_K_f32                        0x12cf6ac50 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q6_K_f32                        0x11e047420 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_iq2_xxs_f32                     0x11e047890 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_iq2_xs_f32                      0x11cf4dd00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_iq3_xxs_f32                     0x11cf4e170 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_iq3_s_f32                       0x12cf6b270 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_iq2_s_f32                       0x11e047eb0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_iq1_s_f32                       0x11e155b10 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_iq1_m_f32                       0x12cf6b890 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_iq4_nl_f32                      0x11e048320 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_iq4_xs_f32                      0x11cf4e430 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_f32_f32                      0x11cf4e8a0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_f16_f32                      0x11cf4ed10 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_mul_mm_id_bf16_f32                (not supported)
# ggml_metal_init: loaded kernel_mul_mm_id_q4_0_f32                     0x11cf4efd0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_q4_1_f32                     0x11cf4f440 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_q5_0_f32                     0x11e0485e0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_q5_1_f32                     0x11e048a50 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_q8_0_f32                     0x11cf4f8b0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_q2_K_f32                     0x11cf4fd20 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_q3_K_f32                     0x11e156490 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_q4_K_f32                     0x11cf50190 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_q5_K_f32                     0x11e156750 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_q6_K_f32                     0x12cf6beb0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_iq2_xxs_f32                  0x11e156bc0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_iq2_xs_f32                   0x11e156e80 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_iq3_xxs_f32                  0x12cf6c320 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_iq3_s_f32                    0x12cf6c790 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_iq2_s_f32                    0x11e049070 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_iq1_s_f32                    0x12cf6cc00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_iq1_m_f32                    0x11e049330 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_iq4_nl_f32                   0x12cf6d220 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_iq4_xs_f32                   0x11e1572f0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_rope_norm_f32                          0x11e157760 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_rope_norm_f16                          0x11cf50600 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_rope_neox_f32                          0x11cf50a70 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_rope_neox_f16                          0x11cf50ee0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_im2col_f16                             0x11cf51350 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_im2col_f32                             0x11cf517c0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_im2col_ext_f16                         0x12cf6d4e0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_im2col_ext_f32                         0x11cf51de0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_conv_transpose_1d_f32_f32              0x11e0497a0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_conv_transpose_1d_f16_f32              0x11e049c10 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_upscale_f32                            0x11e04a080 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_pad_f32                                0x11e04a4f0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_pad_reflect_1d_f32                     0x11cf52250 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_timestep_embedding_f32                 0x11e04a960 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_arange_f32                             0x11e04add0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_argsort_f32_i32_asc                    0x11e04b240 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_argsort_f32_i32_desc                   0x11cf52510 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_leaky_relu_f32                         0x11cf52ea0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_f16_h64                 0x11cf53160 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_f16_h80                 0x11cf535d0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_f16_h96                 0x12cf6d7a0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_f16_h112                0x12cf6de80 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_f16_h128                0x11cf53890 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_f16_h256                0x11cf53d00 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_flash_attn_ext_bf16_h64           (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_bf16_h80           (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_bf16_h96           (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_bf16_h112          (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_bf16_h128          (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_bf16_h256          (not supported)
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_0_h64                0x11e157bd0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_0_h80                0x11e04ba10 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_0_h96                0x11e1581f0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_0_h112               0x12cf6e140 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_0_h128               0x11e158660 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_0_h256               0x11e158ad0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_1_h64                0x11e04bcd0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_1_h80                0x11e158d90 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_1_h96                0x12cf6e760 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_1_h112               0x11cf54170 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_1_h128               0x11cf545e0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_1_h256               0x11e04c2f0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_0_h64                0x11e159200 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_0_h80                0x11e159670 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_0_h96                0x11cf548a0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_0_h112               0x12cf6ed80 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_0_h128               0x11cf54b60 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_0_h256               0x11cf54fd0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_1_h64                0x11e159ae0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_1_h80                0x11e159f50 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_1_h96                0x11e15a3c0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_1_h112               0x11e04c910 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_1_h128               0x11cf55440 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_1_h256               0x11e04cd80 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q8_0_h64                0x12cf6f550 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q8_0_h80                0x12cf6f9c0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q8_0_h96                0x11cf55700 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q8_0_h112               0x12cf6fe30 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q8_0_h128               0x11e15a680 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q8_0_h256               0x11e15aaf0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_f16_h128            0x11cf55b70 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_flash_attn_ext_vec_bf16_h128      (not supported)
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q4_0_h128           0x11cf55e30 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q4_1_h128           0x11e15af60 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q5_0_h128           0x11e15b3d0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q5_1_h128           0x11e04d550 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q8_0_h128           0x11cf562a0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_f16_h256            0x11e04d9c0 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_flash_attn_ext_vec_bf16_h256      (not supported)
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q4_0_h256           0x11e04de30 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q4_1_h256           0x11e15b840 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q5_0_h256           0x11cf56560 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q5_1_h256           0x11cf569d0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q8_0_h256           0x11e15bcb0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_set_f32                                0x11e15c120 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_set_i32                                0x11e15c590 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f32_f32                            0x12cf70450 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f32_f16                            0x12cf708c0 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_cpy_f32_bf16                      (not supported)
# ggml_metal_init: loaded kernel_cpy_f16_f32                            0x11e04e450 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f16_f16                            0x11e04e8c0 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_cpy_bf16_f32                      (not supported)
# ggml_metal_init: skipping kernel_cpy_bf16_bf16                     (not supported)
# ggml_metal_init: loaded kernel_cpy_f32_q8_0                           0x11e04ed30 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f32_q4_0                           0x11e04f1a0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f32_q4_1                           0x12cf70d30 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f32_q5_0                           0x12cf711a0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f32_q5_1                           0x12cf71610 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f32_iq4_nl                         0x11e15ca00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_q4_0_f32                           0x11cf56c90 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_q4_0_f16                           0x11cf57100 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_q4_1_f32                           0x12cf71a80 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_q4_1_f16                           0x12cf71ef0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_q5_0_f32                           0x11e04f610 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_q5_0_f16                           0x11e04fa80 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_q5_1_f32                           0x11e04fef0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_q5_1_f16                           0x11e050360 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_q8_0_f32                           0x12cf72360 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_q8_0_f16                           0x12cf727d0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_concat                                 0x11e15d020 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_sqr                                    0x11e050a50 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_sqrt                                   0x12cf72ec0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_sin                                    0x11e051140 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cos                                    0x12cf735b0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_sum_rows                               0x12cf73a20 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_argmax                                 0x12cf73e90 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_pool_2d_avg_f32                        0x12cf74300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_pool_2d_max_f32                        0x12cf74770 | th_max = 1024 | th_width =   32
# llama_kv_cache_init: kv_size = 8192, offload = 1, type_k = 'f16', type_v = 'f16', n_layer = 32, can_shift = 1
# llama_kv_cache_init: layer 0: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 1: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 2: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 3: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 4: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 5: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 6: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 7: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 8: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 9: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 10: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 11: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 12: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 13: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 14: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 15: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 16: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 17: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 18: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 19: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 20: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 21: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 22: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 23: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 24: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 25: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 26: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 27: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 28: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 29: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 30: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 31: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init:        CPU KV buffer size =  1024.00 MiB
# llama_init_from_model: KV self size  = 1024.00 MiB, K (f16):  512.00 MiB, V (f16):  512.00 MiB
# llama_init_from_model:        CPU  output buffer size =     0.12 MiB
# llama_init_from_model:        CPU compute buffer size =   560.01 MiB
# llama_init_from_model: graph nodes  = 1030
# llama_init_from_model: graph splits = 514 (with bs=512), 1 (with bs=1)
# Metal : EMBED_LIBRARY = 1 | CPU : NEON = 1 | ARM_FMA = 1 | FP16_VA = 1 | MATMUL_INT8 = 1 | DOTPROD = 1 | ACCELERATE = 1 | AARCH64_REPACK = 1 |
# Model metadata: {'general.quantization_version': '2', 'tokenizer.chat_template': "{{ bos_token }}{% for message in messages %}{% if (message['role'] == 'user') != (loop.index0 % 2 == 0) %}{{ raise_exception('Conversation roles must alternate user/assistant/user/assistant/...') }}{% endif %}{% if message['role'] == 'user' %}{{ '[INST] ' + message['content'] + ' [/INST]' }}{% elif message['role'] == 'assistant' %}{{ message['content'] + eos_token}}{% else %}{{ raise_exception('Only user and assistant roles are supported!') }}{% endif %}{% endfor %}", 'tokenizer.ggml.add_eos_token': 'false', 'tokenizer.ggml.add_bos_token': 'true', 'tokenizer.ggml.padding_token_id': '0', 'tokenizer.ggml.unknown_token_id': '0', 'tokenizer.ggml.eos_token_id': '2', 'tokenizer.ggml.bos_token_id': '1', 'tokenizer.ggml.model': 'llama', 'llama.attention.head_count_kv': '8', 'llama.context_length': '32768', 'llama.attention.head_count': '32', 'llama.rope.freq_base': '1000000.000000', 'llama.rope.dimension_count': '128', 'general.file_type': '15', 'llama.feed_forward_length': '14336', 'llama.embedding_length': '4096', 'llama.block_count': '32', 'general.architecture': 'llama', 'llama.attention.layer_norm_rms_epsilon': '0.000010', 'general.name': 'mistralai_mistral-7b-instruct-v0.2'}
# Available chat formats from metadata: chat_template.default
# Guessed chat format: mistral-instruct
# llama_perf_context_print:        load time =   39771.25 ms
# llama_perf_context_print: prompt eval time =   39770.34 ms /  1570 tokens (   25.33 ms per token,    39.48 tokens per second)
# llama_perf_context_print:        eval time =   32870.27 ms /   445 runs   (   73.87 ms per token,    13.54 tokens per second)
# llama_perf_context_print:       total time =   72775.18 ms /  2015 tokens
# ggml_metal_free: deallocating
# ✅ JSON saved to: ../data/output/extracted_knowledge.json

# %% [markdown]
# ## Load and View the Extracted JSON Output
#
# Explicitly load and display the generated JSON to confirm extraction results.

# %%
import json

# Load JSON output explicitly
with open(output_json_path, "r", encoding="utf-8") as file:
    extracted_data = json.load(file)

# Clearly display the extracted data
extracted_data
# Out:
# {'pollutants': {'ParticulateMatter': ['PM10'],
#   'GaseousPollutants': ['NO2'],
#   'TraceElements': [],
#   'HazardousOrganicCompounds': [],
#   'Uncategorized': []},
#  'pollution_sources': {'MobileSource': ['Traffic sector', 'Hybrid cars'],
#   'StationarySource': ['Factories',
#    'Industrial sector',
#    'Residential sector',
#    'Fireplaces'],
#   'AreaSource': [],
#   'AgriculturalSource': [],
#   'NaturalSource': [],
#   'Uncategorized': ['TAPM']},
#  'mitigation_measures': {'PolicyBasedMeasure': ['Air Quality Plans'],
#   'TechnologicalMeasure': ['LEZ'],
#   'Uncategorized': ['Fireplaces regulations', 'Industry regulations']},
#  'meteorological_factors': [],
#  'street_canyons': [],
#  'pollutant_source_relations': [['PM10', 'Residential sector'],
#   ['PM10', 'Industrial sector'],
#   ['NO2', 'Traffic sector']],
#  'source_mitigation_relations': [['Residential sector', 'Air Quality Plans'],
#   ['Industrial sector', 'Fireplaces regulations'],
#   ['Industrial sector', 'Industry regulations'],
#   ['Traffic sector', 'Hybrid cars'],
#   ['Traffic sector', 'LEZ']],
#  'meteorological_dispersion_relations': [],
#  'street_canyon_dispersion_relations': [],
#  'mitigation_effects': {'ReductionPercentage': ['4.5%']}}
