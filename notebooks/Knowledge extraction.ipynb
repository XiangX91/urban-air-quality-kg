# %% [markdown]
# ## Import the Extraction Function
# !pip install -r ../requirements.txt
#
# Clearly import the custom extraction function from the `src/extraction.py` module.

# %%
import sys
from pathlib import Path

# Clearly add parent directory (to access src folder)
sys.path.append(str(Path.cwd().parent))

# Import your extraction function explicitly
from src.extraction import extract_json_from_text

# %% [markdown]
# ## Define File Paths
#
# Clearly specify paths to:
#
# - Input text file (`example.txt`)
# - Ontology YAML file (`urban_air_quality.yaml`)
# - Output JSON file (`extracted_knowledge.json`)
# - LLM model file (`.gguf` model file)

# %%
# Clearly defined file paths
input_txt_path = Path("../data/example txt/example.txt")
ontology_yaml_path = Path("../ontology/urban_air_quality.yaml")
output_json_path = Path("../data/output/extracted_knowledge.json")
model_path = Path("mistral-7b-instruct-v0.2.Q4_K_M.gguf")  # <-- explicitly replace this path

# %% [markdown]
# ## Run Extraction Function
#
# Execute the extraction function clearly to generate the structured JSON output.

# %%
extract_json_from_text(
    input_txt_path=input_txt_path,
    ontology_yaml_path=ontology_yaml_path,
    output_json_path=output_json_path,
    model_path=model_path
)
# Out:
# llama_model_load_from_file_impl: using device Metal (Apple M3 Pro) - 12287 MiB free
# llama_model_loader: loaded meta data with 24 key-value pairs and 291 tensors from /Users/nxx20/Library/Application Support/nomic.ai/GPT4All/mistral-7b-instruct-v0.2.Q4_K_M.gguf (version GGUF V3 (latest))
# llama_model_loader: Dumping metadata keys/values. Note: KV overrides do not apply in this output.
# llama_model_loader: - kv   0:                       general.architecture str              = llama
# llama_model_loader: - kv   1:                               general.name str              = mistralai_mistral-7b-instruct-v0.2
# llama_model_loader: - kv   2:                       llama.context_length u32              = 32768
# llama_model_loader: - kv   3:                     llama.embedding_length u32              = 4096
# llama_model_loader: - kv   4:                          llama.block_count u32              = 32
# llama_model_loader: - kv   5:                  llama.feed_forward_length u32              = 14336
# llama_model_loader: - kv   6:                 llama.rope.dimension_count u32              = 128
# llama_model_loader: - kv   7:                 llama.attention.head_count u32              = 32
# llama_model_loader: - kv   8:              llama.attention.head_count_kv u32              = 8
# llama_model_loader: - kv   9:     llama.attention.layer_norm_rms_epsilon f32              = 0.000010
# llama_model_loader: - kv  10:                       llama.rope.freq_base f32              = 1000000.000000
# llama_model_loader: - kv  11:                          general.file_type u32              = 15
# llama_model_loader: - kv  12:                       tokenizer.ggml.model str              = llama
# llama_model_loader: - kv  13:                      tokenizer.ggml.tokens arr[str,32000]   = ["<unk>", "<s>", "</s>", "<0x00>", "<...
# llama_model_loader: - kv  14:                      tokenizer.ggml.scores arr[f32,32000]   = [0.000000, 0.000000, 0.000000, 0.0000...
# llama_model_loader: - kv  15:                  tokenizer.ggml.token_type arr[i32,32000]   = [2, 3, 3, 6, 6, 6, 6, 6, 6, 6, 6, 6, ...
# llama_model_loader: - kv  16:                tokenizer.ggml.bos_token_id u32              = 1
# llama_model_loader: - kv  17:                tokenizer.ggml.eos_token_id u32              = 2
# llama_model_loader: - kv  18:            tokenizer.ggml.unknown_token_id u32              = 0
# llama_model_loader: - kv  19:            tokenizer.ggml.padding_token_id u32              = 0
# llama_model_loader: - kv  20:               tokenizer.ggml.add_bos_token bool             = true
# llama_model_loader: - kv  21:               tokenizer.ggml.add_eos_token bool             = false
# llama_model_loader: - kv  22:                    tokenizer.chat_template str              = {{ bos_token }}{% for message in mess...
# llama_model_loader: - kv  23:               general.quantization_version u32              = 2
# llama_model_loader: - type  f32:   65 tensors
# llama_model_loader: - type q4_K:  193 tensors
# llama_model_loader: - type q6_K:   33 tensors
# print_info: file format = GGUF V3 (latest)
# print_info: file type   = Q4_K - Medium
# print_info: file size   = 4.07 GiB (4.83 BPW)
# init_tokenizer: initializing tokenizer for type 1
# load: control token:      2 '</s>' is not marked as EOG
# load: control token:      1 '<s>' is not marked as EOG
# load: special_eos_id is not in special_eog_ids - the tokenizer config may be incorrect
# load: special tokens cache size = 3
# load: token to piece cache size = 0.1637 MB
# print_info: arch             = llama
# print_info: vocab_only       = 0
# print_info: n_ctx_train      = 32768
# print_info: n_embd           = 4096
# print_info: n_layer          = 32
# print_info: n_head           = 32
# print_info: n_head_kv        = 8
# print_info: n_rot            = 128
# print_info: n_swa            = 0
# print_info: n_embd_head_k    = 128
# print_info: n_embd_head_v    = 128
# print_info: n_gqa            = 4
# print_info: n_embd_k_gqa     = 1024
# print_info: n_embd_v_gqa     = 1024
# print_info: f_norm_eps       = 0.0e+00
# print_info: f_norm_rms_eps   = 1.0e-05
# print_info: f_clamp_kqv      = 0.0e+00
# print_info: f_max_alibi_bias = 0.0e+00
# print_info: f_logit_scale    = 0.0e+00
# print_info: f_attn_scale     = 0.0e+00
# print_info: n_ff             = 14336
# print_info: n_expert         = 0
# print_info: n_expert_used    = 0
# print_info: causal attn      = 1
# print_info: pooling type     = 0
# print_info: rope type        = 0
# print_info: rope scaling     = linear
# print_info: freq_base_train  = 1000000.0
# print_info: freq_scale_train = 1
# print_info: n_ctx_orig_yarn  = 32768
# print_info: rope_finetuned   = unknown
# print_info: ssm_d_conv       = 0
# print_info: ssm_d_inner      = 0
# print_info: ssm_d_state      = 0
# print_info: ssm_dt_rank      = 0
# print_info: ssm_dt_b_c_rms   = 0
# print_info: model type       = 7B
# print_info: model params     = 7.24 B
# print_info: general.name     = mistralai_mistral-7b-instruct-v0.2
# print_info: vocab type       = SPM
# print_info: n_vocab          = 32000
# print_info: n_merges         = 0
# print_info: BOS token        = 1 '<s>'
# print_info: EOS token        = 2 '</s>'
# print_info: UNK token        = 0 '<unk>'
# print_info: PAD token        = 0 '<unk>'
# print_info: LF token         = 13 '<0x0A>'
# print_info: EOG token        = 2 '</s>'
# print_info: max token length = 48
# load_tensors: loading model tensors, this can take a while... (mmap = true)
# load_tensors: layer   0 assigned to device CPU
# load_tensors: layer   1 assigned to device CPU
# load_tensors: layer   2 assigned to device CPU
# load_tensors: layer   3 assigned to device CPU
# load_tensors: layer   4 assigned to device CPU
# load_tensors: layer   5 assigned to device CPU
# load_tensors: layer   6 assigned to device CPU
# load_tensors: layer   7 assigned to device CPU
# load_tensors: layer   8 assigned to device CPU
# load_tensors: layer   9 assigned to device CPU
# load_tensors: layer  10 assigned to device CPU
# load_tensors: layer  11 assigned to device CPU
# load_tensors: layer  12 assigned to device CPU
# load_tensors: layer  13 assigned to device CPU
# load_tensors: layer  14 assigned to device CPU
# load_tensors: layer  15 assigned to device CPU
# load_tensors: layer  16 assigned to device CPU
# load_tensors: layer  17 assigned to device CPU
# load_tensors: layer  18 assigned to device CPU
# load_tensors: layer  19 assigned to device CPU
# load_tensors: layer  20 assigned to device CPU
# load_tensors: layer  21 assigned to device CPU
# load_tensors: layer  22 assigned to device CPU
# load_tensors: layer  23 assigned to device CPU
# load_tensors: layer  24 assigned to device CPU
# load_tensors: layer  25 assigned to device CPU
# load_tensors: layer  26 assigned to device CPU
# load_tensors: layer  27 assigned to device CPU
# load_tensors: layer  28 assigned to device CPU
# load_tensors: layer  29 assigned to device CPU
# load_tensors: layer  30 assigned to device CPU
# load_tensors: layer  31 assigned to device CPU
# load_tensors: layer  32 assigned to device CPU
# load_tensors: tensor 'token_embd.weight' (q4_K) (and 290 others) cannot be used with preferred buffer type CPU_AARCH64, using CPU instead
# load_tensors: offloading 0 repeating layers to GPU
# load_tensors: offloaded 0/33 layers to GPU
# load_tensors:   CPU_Mapped model buffer size =  4165.37 MiB
# .................................................................................................
# llama_init_from_model: n_seq_max     = 1
# llama_init_from_model: n_ctx         = 8192
# llama_init_from_model: n_ctx_per_seq = 8192
# llama_init_from_model: n_batch       = 512
# llama_init_from_model: n_ubatch      = 512
# llama_init_from_model: flash_attn    = 0
# llama_init_from_model: freq_base     = 1000000.0
# llama_init_from_model: freq_scale    = 1
# llama_init_from_model: n_ctx_per_seq (8192) < n_ctx_train (32768) -- the full capacity of the model will not be utilized
# ggml_metal_init: allocating
# ggml_metal_init: found device: Apple M3 Pro
# ggml_metal_init: picking default device: Apple M3 Pro
# ggml_metal_load_library: using embedded metal library
# ggml_metal_init: GPU name:   Apple M3 Pro
# ggml_metal_init: GPU family: MTLGPUFamilyApple9  (1009)
# ggml_metal_init: GPU family: MTLGPUFamilyCommon3 (3003)
# ggml_metal_init: GPU family: MTLGPUFamilyMetal3  (5001)
# ggml_metal_init: simdgroup reduction   = true
# ggml_metal_init: simdgroup matrix mul. = true
# ggml_metal_init: has residency sets    = true
# ggml_metal_init: has bfloat            = true
# ggml_metal_init: use bfloat            = false
# ggml_metal_init: hasUnifiedMemory      = true
# ggml_metal_init: recommendedMaxWorkingSetSize  = 12884.92 MB
# ggml_metal_init: loaded kernel_add                                    0x111b33b60 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_add_row                                0x111a53c80 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_sub                                    0x11180e230 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_sub_row                                0x111b33e20 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul                                    0x11180e4f0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_row                                0x111b35350 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_div                                    0x111b2f3b0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_div_row                                0x11180e7b0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_repeat_f32                             0x111c12db0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_repeat_f16                             0x11180ea70 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_repeat_i32                             0x11180ed30 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_repeat_i16                             0x111a545c0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_scale                                  0x111b378c0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_scale_4                                0x11180f300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_clamp                                  0x111b38060 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_tanh                                   0x111c132f0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_relu                                   0x111c139e0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_sigmoid                                0x111c140d0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_gelu                                   0x111c147c0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_gelu_4                                 0x111c15140 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_gelu_quick                             0x111c15830 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_gelu_quick_4                           0x11180f840 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_silu                                   0x111b38750 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_silu_4                                 0x111c15fe0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_elu                                    0x11180fd80 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_soft_max_f16                           0x111810040 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_soft_max_f16_4                         0x111810300 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_soft_max_f32                           0x111a59e70 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_soft_max_f32_4                         0x111b39840 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_diag_mask_inf                          0x1118105c0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_diag_mask_inf_8                        0x111b39cb0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_f32                           0x111b3a120 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_f16                           0x111b3a590 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_get_rows_bf16                     (not supported)
# ggml_metal_init: loaded kernel_get_rows_q4_0                          0x111c162a0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q4_1                          0x111b3aa00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q5_0                          0x11180aab0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q5_1                          0x111a5a130 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q8_0                          0x111b3acc0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q2_K                          0x11180d710 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q3_K                          0x111b3b2e0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q4_K                          0x111a5a3f0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q5_K                          0x111c168f0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_q6_K                          0x111c16d90 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq2_xxs                       0x111a5a6b0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq2_xs                        0x11180c580 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq3_xxs                       0x111a5a970 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq3_s                         0x131063680 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq2_s                         0x111b3bac0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq1_s                         0x111b3bf60 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq1_m                         0x111c17230 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq4_nl                        0x111c176d0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_iq4_xs                        0x111810fe0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_get_rows_i32                           0x11180b320 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_rms_norm                               0x1310645a0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_group_norm                             0x131063c70 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_norm                                   0x1310662e0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_ssm_conv_f32                           0x111b3c220 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_ssm_scan_f32                           0x111b3c720 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_f32_f32                         0x111811860 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_mul_mv_bf16_f32                   (not supported)
# ggml_metal_init: skipping kernel_mul_mv_bf16_f32_1row              (not supported)
# ggml_metal_init: skipping kernel_mul_mv_bf16_f32_l4                (not supported)
# ggml_metal_init: skipping kernel_mul_mv_bf16_bf16                  (not supported)
# ggml_metal_init: loaded kernel_mul_mv_f16_f32                         0x110e051c0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_f16_f32_1row                    0x131105250 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_f16_f32_l4                      0x130f06ac0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_f16_f16                         0x110e05630 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q4_0_f32                        0x111b3ccd0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q4_1_f32                        0x111a5ac30 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q5_0_f32                        0x131065b50 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q5_1_f32                        0x111b3d1e0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q8_0_f32                        0x111b3d6f0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_f16_f32_r1_2                0x111b3dc00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_f16_f32_r1_3                0x111b3dec0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_f16_f32_r1_4                0x111811db0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_f16_f32_r1_5                0x131062660 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_0_f32_r1_2               0x131066ea0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_0_f32_r1_3               0x131067160 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_0_f32_r1_4               0x1310675d0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_0_f32_r1_5               0x111a5aef0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_1_f32_r1_2               0x111a5b1b0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_1_f32_r1_3               0x111a5b8f0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_1_f32_r1_4               0x111a5bbb0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_1_f32_r1_5               0x111a559b0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_0_f32_r1_2               0x111a55c70 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_0_f32_r1_3               0x1118124b0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_0_f32_r1_4               0x111812770 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_0_f32_r1_5               0x111b3e450 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_1_f32_r1_2               0x111b3e710 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_1_f32_r1_3               0x131067da0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_1_f32_r1_4               0x111b3eca0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_1_f32_r1_5               0x111812cc0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q8_0_f32_r1_2               0x131068210 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q8_0_f32_r1_3               0x111a57b90 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q8_0_f32_r1_4               0x1310684d0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q8_0_f32_r1_5               0x131068940 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_K_f32_r1_2               0x131069130 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_K_f32_r1_3               0x131069680 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_K_f32_r1_4               0x131069940 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q4_K_f32_r1_5               0x111b3f260 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_K_f32_r1_2               0x111b3f820 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_K_f32_r1_3               0x111b3b5a0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_K_f32_r1_4               0x131069e90 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q5_K_f32_r1_5               0x1118139b0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q6_K_f32_r1_2               0x111813f00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q6_K_f32_r1_3               0x111b3ff90 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q6_K_f32_r1_4               0x1118141c0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_q6_K_f32_r1_5               0x13106a150 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_iq4_nl_f32_r1_2             0x111814710 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_iq4_nl_f32_r1_3             0x111814c60 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_iq4_nl_f32_r1_4             0x111b40400 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_ext_iq4_nl_f32_r1_5             0x111814f20 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q2_K_f32                        0x1118153c0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q3_K_f32                        0x13106a950 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q4_K_f32                        0x13106adf0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q5_K_f32                        0x111a58b10 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_q6_K_f32                        0x111a561e0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq2_xxs_f32                     0x111815860 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq2_xs_f32                      0x111a564a0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq3_xxs_f32                     0x111a56760 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq3_s_f32                       0x111a56a20 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq2_s_f32                       0x111b40ca0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq1_s_f32                       0x111b40f60 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq1_m_f32                       0x13106b290 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq4_nl_f32                      0x13106b730 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_iq4_xs_f32                      0x13106b9f0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_f32_f32                      0x13106be90 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_f16_f32                      0x13106c330 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_mul_mv_id_bf16_f32                (not supported)
# ggml_metal_init: loaded kernel_mul_mv_id_q4_0_f32                     0x111816060 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q4_1_f32                     0x111816500 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q5_0_f32                     0x150e0a730 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q5_1_f32                     0x1118167c0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q8_0_f32                     0x111b41980 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q2_K_f32                     0x111816a80 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q3_K_f32                     0x13106c9b0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q4_K_f32                     0x13106ce50 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q5_K_f32                     0x111a56ce0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_q6_K_f32                     0x111a5c1a0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq2_xxs_f32                  0x111a5c460 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq2_xs_f32                   0x111a5c720 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq3_xxs_f32                  0x111b42180 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq3_s_f32                    0x111816f20 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq2_s_f32                    0x111a5c9e0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq1_s_f32                    0x111a5cca0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq1_m_f32                    0x111a5d210 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq4_nl_f32                   0x13106d2f0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mv_id_iq4_xs_f32                   0x1118173c0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_f32_f32                         0x111b42620 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_f16_f32                         0x111817860 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_mul_mm_bf16_f32                   (not supported)
# ggml_metal_init: loaded kernel_mul_mm_q4_0_f32                        0x111817d00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q4_1_f32                        0x1118181a0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q5_0_f32                        0x13106d790 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q5_1_f32                        0x111b42ac0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q8_0_f32                        0x13106dc30 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q2_K_f32                        0x13106e0d0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q3_K_f32                        0x13106e570 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q4_K_f32                        0x13106ea10 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q5_K_f32                        0x111b42f60 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_q6_K_f32                        0x13106eeb0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_iq2_xxs_f32                     0x111a5d4d0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_iq2_xs_f32                      0x111a5d790 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_iq3_xxs_f32                     0x111a5da50 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_iq3_s_f32                       0x111a5df80 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_iq2_s_f32                       0x111818640 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_iq1_s_f32                       0x111818ae0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_iq1_m_f32                       0x111818f80 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_iq4_nl_f32                      0x111a5e240 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_iq4_xs_f32                      0x111b43400 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_f32_f32                      0x111a5e500 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_f16_f32                      0x111a5e7c0 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_mul_mm_id_bf16_f32                (not supported)
# ggml_metal_init: loaded kernel_mul_mm_id_q4_0_f32                     0x111a5ea80 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_q4_1_f32                     0x111a5ed40 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_q5_0_f32                     0x111b438a0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_q5_1_f32                     0x111819420 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_q8_0_f32                     0x111a5f1e0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_q2_K_f32                     0x1118198c0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_q3_K_f32                     0x111a5f680 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_q4_K_f32                     0x111a5fb20 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_q5_K_f32                     0x111b43d40 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_q6_K_f32                     0x111b441e0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_iq2_xxs_f32                  0x13106f350 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_iq2_xs_f32                   0x111a5fde0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_iq3_xxs_f32                  0x111a60280 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_iq3_s_f32                    0x111a60720 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_iq2_s_f32                    0x111a60bc0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_iq1_s_f32                    0x13106f610 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_iq1_m_f32                    0x13106fab0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_iq4_nl_f32                   0x13106ff50 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_mul_mm_id_iq4_xs_f32                   0x111b44830 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_rope_norm_f32                          0x111b44d80 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_rope_norm_f16                          0x111b452d0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_rope_neox_f32                          0x111b45820 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_rope_neox_f16                          0x111b45d70 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_im2col_f16                             0x111b46030 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_im2col_f32                             0x111b464d0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_im2col_ext_f16                         0x111b46790 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_im2col_ext_f32                         0x111a61210 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_conv_transpose_1d_f32_f32              0x111b46c30 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_conv_transpose_1d_f16_f32              0x1310703f0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_upscale_f32                            0x131070940 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_pad_f32                                0x111819f10 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_pad_reflect_1d_f32                     0x111a616b0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_timestep_embedding_f32                 0x11181a3b0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_arange_f32                             0x131070f90 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_argsort_f32_i32_asc                    0x111b470d0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_argsort_f32_i32_desc                   0x131071430 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_leaky_relu_f32                         0x11181ac00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_f16_h64                 0x11181aec0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_f16_h80                 0x111a61c00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_f16_h96                 0x11181b5c0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_f16_h112                0x111a61ec0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_f16_h128                0x131071980 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_f16_h256                0x111b477d0 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_flash_attn_ext_bf16_h64           (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_bf16_h80           (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_bf16_h96           (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_bf16_h112          (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_bf16_h128          (not supported)
# ggml_metal_init: skipping kernel_flash_attn_ext_bf16_h256          (not supported)
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_0_h64                0x111a62410 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_0_h80                0x11181bb10 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_0_h96                0x111b47a90 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_0_h112               0x111b47d50 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_0_h128               0x131071c40 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_0_h256               0x11181c3c0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_1_h64                0x111a62960 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_1_h80                0x11181c910 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_1_h96                0x11181cbd0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_1_h112               0x11181d120 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_1_h128               0x11181d670 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q4_1_h256               0x111b482a0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_0_h64                0x111b487f0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_0_h80                0x111b48d40 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_0_h96                0x131072190 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_0_h112               0x131072450 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_0_h128               0x111a62e00 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_0_h256               0x111b495f0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_1_h64                0x111a63350 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_1_h80                0x111a63610 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_1_h96                0x11181dbc0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_1_h112               0x111a638d0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_1_h128               0x111a63b90 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q5_1_h256               0x111a640e0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q8_0_h64                0x111a64630 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q8_0_h80                0x1310729a0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q8_0_h96                0x131072ef0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q8_0_h112               0x1310731b0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q8_0_h128               0x131073700 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_q8_0_h256               0x131073c50 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_f16_h128            0x1310741a0 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_flash_attn_ext_vec_bf16_h128      (not supported)
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q4_0_h128           0x111b4a050 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q4_1_h128           0x11181e2c0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q5_0_h128           0x11181e810 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q5_1_h128           0x11181ed60 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q8_0_h128           0x111b4a5a0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_f16_h256            0x11181f2b0 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_flash_attn_ext_vec_bf16_h256      (not supported)
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q4_0_h256           0x11181f800 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q4_1_h256           0x111a64d30 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q5_0_h256           0x111a65280 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q5_1_h256           0x111b4aaf0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_flash_attn_ext_vec_q8_0_h256           0x11181fac0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_set_f32                                0x11181ff60 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_set_i32                                0x111820400 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f32_f32                            0x111a658d0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f32_f16                            0x1118208a0 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_cpy_f32_bf16                      (not supported)
# ggml_metal_init: loaded kernel_cpy_f16_f32                            0x111a65d70 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f16_f16                            0x111a66210 | th_max = 1024 | th_width =   32
# ggml_metal_init: skipping kernel_cpy_bf16_f32                      (not supported)
# ggml_metal_init: skipping kernel_cpy_bf16_bf16                     (not supported)
# ggml_metal_init: loaded kernel_cpy_f32_q8_0                           0x111b4af90 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f32_q4_0                           0x111a666b0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f32_q4_1                           0x111820d40 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f32_q5_0                           0x111b4b250 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f32_q5_1                           0x111c17d20 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_f32_iq4_nl                         0x111c181c0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_q4_0_f32                           0x131074460 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_q4_0_f16                           0x131074900 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_q4_1_f32                           0x131074da0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_q4_1_f16                           0x111b4b6f0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_q5_0_f32                           0x111b4bb90 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_q5_0_f16                           0x111b4c030 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_q5_1_f32                           0x111b4c2f0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_q5_1_f16                           0x111a66b50 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_q8_0_f32                           0x111a66e10 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cpy_q8_0_f16                           0x111a672b0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_concat                                 0x111b4c840 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_sqr                                    0x111b4cf60 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_sqrt                                   0x111c188e0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_sin                                    0x111c19000 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_cos                                    0x111a677f0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_sum_rows                               0x111a67d40 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_argmax                                 0x111b4d400 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_pool_2d_avg_f32                        0x111c194a0 | th_max = 1024 | th_width =   32
# ggml_metal_init: loaded kernel_pool_2d_max_f32                        0x131075900 | th_max = 1024 | th_width =   32
# llama_kv_cache_init: kv_size = 8192, offload = 1, type_k = 'f16', type_v = 'f16', n_layer = 32, can_shift = 1
# llama_kv_cache_init: layer 0: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 1: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 2: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 3: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 4: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 5: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 6: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 7: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 8: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 9: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 10: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 11: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 12: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 13: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 14: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 15: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 16: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 17: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 18: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 19: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 20: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 21: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 22: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 23: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 24: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 25: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 26: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 27: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 28: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 29: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 30: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init: layer 31: n_embd_k_gqa = 1024, n_embd_v_gqa = 1024
# llama_kv_cache_init:        CPU KV buffer size =  1024.00 MiB
# llama_init_from_model: KV self size  = 1024.00 MiB, K (f16):  512.00 MiB, V (f16):  512.00 MiB
# llama_init_from_model:        CPU  output buffer size =     0.12 MiB
# llama_init_from_model:        CPU compute buffer size =   560.01 MiB
# llama_init_from_model: graph nodes  = 1030
# llama_init_from_model: graph splits = 514 (with bs=512), 1 (with bs=1)
# Metal : EMBED_LIBRARY = 1 | CPU : NEON = 1 | ARM_FMA = 1 | FP16_VA = 1 | MATMUL_INT8 = 1 | DOTPROD = 1 | ACCELERATE = 1 | AARCH64_REPACK = 1 |
# Model metadata: {'general.quantization_version': '2', 'tokenizer.chat_template': "{{ bos_token }}{% for message in messages %}{% if (message['role'] == 'user') != (loop.index0 % 2 == 0) %}{{ raise_exception('Conversation roles must alternate user/assistant/user/assistant/...') }}{% endif %}{% if message['role'] == 'user' %}{{ '[INST] ' + message['content'] + ' [/INST]' }}{% elif message['role'] == 'assistant' %}{{ message['content'] + eos_token}}{% else %}{{ raise_exception('Only user and assistant roles are supported!') }}{% endif %}{% endfor %}", 'tokenizer.ggml.add_eos_token': 'false', 'tokenizer.ggml.add_bos_token': 'true', 'tokenizer.ggml.padding_token_id': '0', 'tokenizer.ggml.unknown_token_id': '0', 'tokenizer.ggml.eos_token_id': '2', 'tokenizer.ggml.bos_token_id': '1', 'tokenizer.ggml.model': 'llama', 'llama.attention.head_count_kv': '8', 'llama.context_length': '32768', 'llama.attention.head_count': '32', 'llama.rope.freq_base': '1000000.000000', 'llama.rope.dimension_count': '128', 'general.file_type': '15', 'llama.feed_forward_length': '14336', 'llama.embedding_length': '4096', 'llama.block_count': '32', 'general.architecture': 'llama', 'llama.attention.layer_norm_rms_epsilon': '0.000010', 'general.name': 'mistralai_mistral-7b-instruct-v0.2'}
# Available chat formats from metadata: chat_template.default
# Guessed chat format: mistral-instruct
# llama_perf_context_print:        load time =   18927.14 ms
# llama_perf_context_print: prompt eval time =   18926.16 ms /   771 tokens (   24.55 ms per token,    40.74 tokens per second)
# llama_perf_context_print:        eval time =   46207.83 ms /   746 runs   (   61.94 ms per token,    16.14 tokens per second)
# llama_perf_context_print:       total time =   65430.46 ms /  1517 tokens
# ggml_metal_free: deallocating
# ✅ JSON saved to: ../data/output/extracted_knowledge.json

# %% [markdown]
# ## Load and View the Extracted JSON Output
#
# Explicitly load and display the generated JSON to confirm extraction results.

# %%
import json

# Load JSON output explicitly
with open(output_json_path, "r", encoding="utf-8") as file:
    extracted_data = json.load(file)

# Clearly display the extracted data
extracted_data
# Out:
# {'pollutants': [{'name': 'PM2.5', 'category': 'particulate matter'},
#   {'name': 'PM10', 'category': 'particulate matter'}],
#  'pollution_sources': [{'name': 'Diesel buses', 'source_type': 'stationary'},
#   {'name': 'City center', 'source_type': 'stationary'}],
#  'mitigation_measures': [{'name': 'Selective catalytic reduction technology',
#    'measure_type': 'technology'}],
#  'pollutant_source_relations': [{'pollutant': {'name': 'PM2.5'},
#    'source': {'name': 'Diesel buses'}},
#   {'pollutant': {'name': 'PM10'}, 'source': {'name': 'Diesel buses'}}],
#  'source_mitigation_relations': [{'source': {'name': 'Diesel buses'},
#    'mitigation': {'name': 'Selective catalytic reduction technology'}}],
#  'meteorological_factors': [{'name': 'Temperature inversions'},
#   {'name': 'Wind speed'}],
#  'street_canyon_factors': [{'name': 'Street canyon geometry'}],
#  'total_reduction_percentage': 0.0}
